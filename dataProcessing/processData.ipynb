# %%
import pandas as pd
import numpy as np
import re

# %%
redditAPI = pd.read_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/redditAPIScrape.csv')
redditScrape = pd.read_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/redditScrape.csv')

# %%
narratives = []


for text in redditAPI['text']:
    text = str(text)
    for sentence in text.split('\n'):
        sentence = sentence.lower()
        #remove hyperlinks
        sentence = re.sub(r'http\S+', ' ', sentence)
        #keep only words
        sentence = re.sub(r'[^a-zA-Z\s]', ' ', sentence)
        #remove unnecessary spaces
        sentence = re.sub(r'\s+', ' ', sentence)
        #remove leading and trailing spaces
        sentence = sentence.strip()
        #remove newlines
        sentence = sentence.replace('\n', ' ')
        narratives.append(sentence)
    
 
    

for text in redditScrape['text']:
    text = str(text)
    for sentence in text.split('\n'):
        sentence = sentence.lower()
        #remove hyperlinks
        sentence = re.sub(r'http\S+', ' ', sentence)
        #keep only words and punctuation
        sentence = re.sub(r'[^a-zA-Z\s]', ' ', sentence)
        #remove unnecessary spaces
        sentence = re.sub(r'\s+', ' ', sentence)
        #remove leading and trailing spaces
        sentence = sentence.strip()
        #remove newlines
        sentence = sentence.replace('\n', ' ')
        narratives.append(sentence)

#remove empty strings from list
narratives = list(filter(None, narratives))

#remove duplicates
narratives = list(set(narratives))

# %%
#filter out narratives that are too short
narratives = [narrative for narrative in narratives if len(narrative.split()) > 5]
#filter out narratives that are too long
narratives = [narrative for narrative in narratives if len(narrative.split()) < 40]


#print len(narratives)
print (len(narratives))

#save narratives to csv
df = pd.DataFrame(narratives)
df.to_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/narrativesAfterFiltering.csv', index=False, header=False)
# Out:
# 39655

# %%
words_to_filter = [
    "skateboard",
    "skateboarding",
    "skateboarder",
    "bike",
    "crash",
    "accident",
    "injury",
    "broke",
    "ankle",
    "leg",
    "arm",
    "wrist",
    "knee",
    "head",
    "neck",
    "shoulder",
    "elbow",
    "hip",
]

narratives_filtered = []

for narrative in narratives:
    narrative_words = narrative.split()
    if any(word in narrative_words for word in words_to_filter):
        narratives_filtered.append(str(narrative))

#get narratives that are not in narratives_filtered
narratives_not_in_filtered = [narrative for narrative in narratives if narrative not in narratives_filtered]

#get 800 random narratives from narratives_not_in_filtered
narratives_not_in_filtered = np.random.choice(narratives_not_in_filtered, 800, replace=False)

#combine narratives_filtered and narratives_not_in_filtered
narratives_filtered = narratives_filtered + narratives_not_in_filtered.tolist()

#shuffle narratives_filtered
np.random.shuffle(narratives_filtered)

#covvert everything to string
narratives_filtered = [str(narrative) for narrative in narratives_filtered]

#print len(narratives_filtered)
print (len(narratives_filtered))
# Out:
# 5892

# %%
words_to_filter = [
    "skateboard",
    "skateboarding",
    "skateboarder",
    "bike",
    "crash",
    "accident",
    "injury",
    "broke",
    "ankle",
    "leg",
    "arm",
    "wrist",
    "knee",
    "head",
    "neck",
    "shoulder",
    "elbow",
    "hip",
]

labelled_narratives = {}

for narrative in narratives_filtered:
    narrative_words = narrative.split()
    if any(word in narrative_words for word in words_to_filter):
        print(narrative)

        #convert to string
        narrative = str(narrative)

        #get user input for label
        label = input("Enter label: ")

        #condition to exit loop
        if label == "exit":
            break

        #if label is not 0 or 1, ask for input again
        while label != "0" and label != "1":
            label = input("Enter label: ")

        #convert label to int 
        label = int(label)
        labelled_narratives[narrative] = label

        #write labelled narratives to csv
        df = pd.DataFrame.from_dict(labelled_narratives, orient='index')
        df.to_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/labelledNarratives.csv', index=False, header=False)

        #print number of labelled narratives
        print (len(labelled_narratives))
# Out:
# this leads to a remake scene from bttf ii where old griff chased marty sr with the hoverboards only in our modern using our more primitive version of hoverboards which many of the upper middle class kids can own in this affluent hill valley the climax is when a car is able to pull out in front of greg on the street causing him to swerve trip off his hoverboard and crash into the back of a manure truck the police arrive to arrest greg for the caf damage and other property damage caused by him as kids nearby take phone pics and tweet the live reaction which will eventually embarrass greg online the driver in the car turns out to be adult aged tiffany tannen ceo of doc brown enterprises who saved marty jr she offers to give marty jr a ride home to lyon estates
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 33
#      30 narrative = str(narrative)
# ...

# %%
#count number of 0s and 1s
count_0 = 0
count_1 = 0
for key, value in labelled_narratives.items():
    if value == 0:
        count_0 += 1
    else:
        count_1 += 1

print (count_0)
print (count_1)

print (len(labelled_narratives))

#save labelled narratives to csv
df = pd.DataFrame()
df['text'] = labelled_narratives.keys()
df['label'] = labelled_narratives.values()

df.to_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/labelledNarratives.csv', index=False)
# Out:
# 0
# 0
# 0

# %%
#read from predicton on reddit data
redditPrediction = pd.read_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/prediction_on_reddit_data.csv')

# %%
#iterate through redditPrediction and get narratives labelled as 1
narratives_labeled_as_one = {}
words_to_look_for = [
    "skateboard",
    "skateboarding",
    "scooter",
    "bike",
    "crash",
    "accident",
    "injury",
    "broke",
    "ankle",
    "leg",
    "arm",
    "wrist",
    "knee",
    "head",
    "neck",
    "shoulder",
    "elbow",
]
for index, row in redditPrediction.iterrows():
    if row['label'] == 1:
        if any(word in row['text'].split() for word in words_to_look_for):
            #append if length of narrative is greater than 5 and less than 40
            if len(row['text'].split()) > 5 and len(row['text'].split()) < 40:
                narratives_labeled_as_one[row['text']] = 1


final_narratives = {}

#iterate through narratives_labeled_as_one and ask user to label them
for narrative in narratives_labeled_as_one:
    print(narrative)

    #convert to string
    narrative = str(narrative)

    #get user input for label
    label = input("Enter label: ")

    #condition to exit loop
    if label == "exit":
        break

    #if label is not 0 or 1, ask for input again
    while label != "0" and label != "1":
        label = input("Enter label: ")

    #convert label to int 
    label = int(label)
    final_narratives[narrative] = label

    #write labelled narratives to csv
    df = pd.DataFrame.from_dict(final_narratives, orient='index')
    df.to_csv('/Users/harmyabhatt/TextMiningAndInjuryClassification/dataFiles/labelledNarrativesFROMPREDICTION.csv', index=False, header=False)

    #print number of labelled narratives
    print (len(final_narratives))
# Out:
# say, for example, you're watching this skateboarding video and these skaters get into accidents, like falling down face\-first or grinding down a railing then slip and land on their genitals.or if you are standing on a bridge and look over the side and see the deep, vast expanse below and then bam! jelly\-like feeling and you are left immobile and crouching.
# 1
# hey all. i’m trying to find a sub where people post their skateboarding fails and bails. some like thrasher’s hall of meat. i haven’t been able to find anything. thanks!
# 2
# i ride a onewheel, which is an electric skateboard. i have had pain in the blade of my lead foot for about a year, which i attributed to also having plantar fasciitis. recently i rolled the ankle of that lead foot while riding and the pain in the blade of that foot got worse.
# 3
# ...
